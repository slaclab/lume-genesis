# %% [markdown]
# # Genesis4 Parsing

# %% [markdown]
# ## Main input files

# %%
from genesis.version4.input import MainInput

# %%
FILE = "data/basic4/cu_hxr.in"

# %% [markdown]
# You can load the main input directly from a file like so:

# %%
input = MainInput.from_file(FILE)

# %%
input.namelists
# Out:
# [Setup(type='setup', rootname='LCLS2_HXR_9keV', outputdir='', lattice='hxr.lat', beamline='HXR', gamma0=19174.0776, lambda0=1.3789244869952112e-10, delz=0.026, seed=84672, npart=1024, nbins=4, one4one=False, shotnoise=True, beam_global_stat=False, field_global_stat=False, exclude_spatial_output=False, exclude_fft_output=False, exclude_intensity_output=False, exclude_energy_output=False, exclude_aux_output=False, exclude_current_output=True, exclude_field_dump=False, write_meta_file=False, semaphore_file_name='', write_semaphore_file=False, write_semaphore_file_done=False, write_semaphore_file_started=False),
#  Time(type='time', s0=0.0, slen=1.5e-05, sample=200, time=True),
#  Field(type='field', lambda_=0.0, power=0.0, phase=0.0, waist_pos=0.0, waist_size=1e-07, xcenter=0.0, ycenter=0.0, xangle=0.0, yangle=0.0, dgrid=0.0001, ngrid=101, harm=1, nx=0, ny=0, accumulate=True),
#  ProfileFile(type='profile_file', label='beamcurrent', xdata='beam_current.h5/s', ydata='beam_current.h5/current', isTime=False, reverse=False, autoassign=False),
#  ProfileFile(type='profile_file', label='beamgamma', xdata='beam_gamma.h5/s', ydata='beam_gamma.h5/gamma', isTime=False, reverse=False, autoassign=False),
#  Beam(type='beam', gamma='@beamgamma', delgam=3.97848, current='@beamcurrent', ex=4e-07, ey=4e-07, betax=7.910909406464387, betay=16.881178621346898, alphax=-0.7393217413918415, alphay=1.3870723536888105, xcenter=0.0, ycenter=0.0, pxcenter=0.0, pycenter=0.0, bunch=0.0, bunchphase=0.0, emod=0.0, emodphase=0.0),
#  Track(type='track', zstop=10.0, output_step=1, field_dump_step=0, beam_dump_step=0, sort_step=0, s0=0.0, slen=0.0, field_dump_at_undexit=False, bunchharm=1)]

# %% [markdown]
# This `input` object is a convenient dataclass which contains all of the namelists and offers some convenience methods.

# %% [markdown]
# We can see the Genesis 4 representation of a namelist by looking at `namelist.to_genesis()`:

# %%
print(input.setup.to_genesis())
# Out:
# &setup
#   rootname = LCLS2_HXR_9keV
#   lattice = hxr.lat
#   beamline = HXR
#   gamma0 = 19174.0776
#   lambda0 = 1.3789244869952112e-10
#   delz = 0.026
#   seed = 84672
#   npart = 1024
# &end

# %% [markdown]
# The parser also works directly with strings if you prefer. Try the following:

# %%
input = MainInput.from_contents(
    """
&setup
  rootname = LCLS2_HXR_9keV
  lattice = hxr.lat
  beamline = HXR
  gamma0 = 19174.0776
  lambda0 = 1.3789244869952112e-10
  delz = 0.026
  seed = 84672
  npart = 1024
&end
"""
)

# %%
input.setup
# Out:
# Setup(type='setup', rootname='LCLS2_HXR_9keV', outputdir='', lattice='hxr.lat', beamline='HXR', gamma0=19174.0776, lambda0=1.3789244869952112e-10, delz=0.026, seed=84672, npart=1024, nbins=4, one4one=False, shotnoise=True, beam_global_stat=False, field_global_stat=False, exclude_spatial_output=False, exclude_fft_output=False, exclude_intensity_output=False, exclude_energy_output=False, exclude_aux_output=False, exclude_current_output=True, exclude_field_dump=False, write_meta_file=False, semaphore_file_name='', write_semaphore_file=False, write_semaphore_file_done=False, write_semaphore_file_started=False)

# %%
input
# Out:
# MainInput(namelists=[Setup(type='setup', rootname='LCLS2_HXR_9keV', outputdir='', lattice='hxr.lat', beamline='HXR', gamma0=19174.0776, lambda0=1.3789244869952112e-10, delz=0.026, seed=84672, npart=1024, nbins=4, one4one=False, shotnoise=True, beam_global_stat=False, field_global_stat=False, exclude_spatial_output=False, exclude_fft_output=False, exclude_intensity_output=False, exclude_energy_output=False, exclude_aux_output=False, exclude_current_output=True, exclude_field_dump=False, write_meta_file=False, semaphore_file_name='', write_semaphore_file=False, write_semaphore_file_done=False, write_semaphore_file_started=False)], filename=PosixPath('unknown'))

# %% [markdown]
# ## Lattice files
#
# Lattice files work in a similar fashion.

# %%
from genesis.version4.input import Lattice

# %%
FILE = "data/basic4/hxr.lat"

# %% [markdown]
# You can load the main input directly from a file like so:

# %%
lat = Lattice.from_file(FILE)

# %%
lat.elements
# Out:
# {'QHXH17': Quadrupole(label='', type='quadrupole', L=0.101, k1=1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH18': Quadrupole(label='', type='quadrupole', L=0.101, k1=-1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH19': Quadrupole(label='', type='quadrupole', L=0.101, k1=1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH20': Quadrupole(label='', type='quadrupole', L=0.101, k1=-1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH21': Quadrupole(label='', type='quadrupole', L=0.101, k1=1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH22': Quadrupole(label='', type='quadrupole', L=0.101, k1=-1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH23': Quadrupole(label='', type='quadrupole', L=0.101, k1=1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH24': Quadrupole(label='', type='quadrupole', L=0.101, k1=-1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH25': Quadrupole(label='', type='quadrupole', L=0.101, k1=1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH26': Quadrupole(label='', type='quadrupole', L=0.101, k1=-1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH27': Quadrupole(label='', type='quadrupole', L=0.101, k1=1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH28': Quadrupole(label='', type='quadrupole', L=0.101, k1=-1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH29': Quadrupole(label='', type='quadrupole', L=0.101, k1=1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH30': Quadrupole(label='', type='quadrupole', L=0.101, k1=-1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH31': Quadrupole(label='', type='quadrupole', L=0.101, k1=1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH32': Quadrupole(label='', type='quadrupole', L=0.101, k1=-1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH33': Quadrupole(label='', type='quadrupole', L=0.101, k1=1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH34': Quadrupole(label='', type='quadrupole', L=0.101, k1=-1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH35': Quadrupole(label='', type='quadrupole', L=0.101, k1=1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH36': Quadrupole(label='', type='quadrupole', L=0.101, k1=-1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH37': Quadrupole(label='', type='quadrupole', L=0.101, k1=1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH38': Quadrupole(label='', type='quadrupole', L=0.101, k1=-1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH39': Quadrupole(label='', type='quadrupole', L=0.101, k1=1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH40': Quadrupole(label='', type='quadrupole', L=0.101, k1=-1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH41': Quadrupole(label='', type='quadrupole', L=0.101, k1=1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH42': Quadrupole(label='', type='quadrupole', L=0.101, k1=-1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH43': Quadrupole(label='', type='quadrupole', L=0.101, k1=1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH44': Quadrupole(label='', type='quadrupole', L=0.101, k1=-1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH45': Quadrupole(label='', type='quadrupole', L=0.101, k1=1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH46': Quadrupole(label='', type='quadrupole', L=0.101, k1=-1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH47': Quadrupole(label='', type='quadrupole', L=0.101, k1=1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH48': Quadrupole(label='', type='quadrupole', L=0.101, k1=-1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH49': Quadrupole(label='', type='quadrupole', L=0.101, k1=1.78, x_offset=0.0, y_offset=0.0),
#  'QHXH50': Quadrupole(label='', type='quadrupole', L=0.101, k1=-1.78, x_offset=0.0, y_offset=0.0),
#  'UMAHXH17': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH18': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH19': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH20': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH21': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH22': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH23': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH25': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH26': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH27': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH28': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH29': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH30': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH31': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH33': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH34': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH35': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH36': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH37': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH38': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH39': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH40': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH41': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH42': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH43': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH44': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH45': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH46': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH47': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH48': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH49': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'UMAHXH50': Undulator(label='', type='undulator', aw=1.7017, lambdau=0.026, nwig=130, helical=False, kx=0.0, ky=1.0, ax=0.0, ay=0.0, gradx=0.0, grady=0.0),
#  'CORR00': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR01': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR02': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR03': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR04': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR05': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR06': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR07': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR08': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR09': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR10': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR11': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR12': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR13': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR14': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR15': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR16': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR17': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR18': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR19': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR20': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR21': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR22': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR23': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR24': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR25': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR26': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR27': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR28': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR29': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR30': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR31': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR32': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'CORR33': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0),
#  'D1': Drift(label='', type='drift', L=0.1335),
#  'D2': Drift(label='', type='drift', L=0.4615),
#  'D3': Drift(label='', type='drift', L=0.328),
#  'D4': Drift(label='', type='drift', L=3.4),
#  'HXRSS': Chicane(label='', type='chicane', L=4.55, lb=0.1, ld=0.0, delay=0.0),
#  'HXR': Line(label='', type='line', elements=['D1', 'UMAHXH17', 'D2', 'QHXH17', 'CORR00', 'D3', 'D1', 'UMAHXH18', 'D2', 'QHXH18', 'CORR01', 'D3', 'D1', 'UMAHXH19', 'D2', 'QHXH19', 'CORR02', 'D3', 'D1', 'UMAHXH20', 'D2', 'QHXH20', 'CORR03', 'D3', 'D1', 'UMAHXH21', 'D2', 'QHXH21', 'CORR04', 'D3', 'D1', 'UMAHXH22', 'D2', 'QHXH22', 'CORR05', 'D3', 'D1', 'UMAHXH23', 'D2', 'QHXH23', 'CORR06', 'D3', 'D1', 'HXRSS', 'D2', 'QHXH24', 'CORR07', 'D3', 'D1', 'UMAHXH25', 'D2', 'QHXH25', 'CORR08', 'D3', 'D1', 'UMAHXH26', 'D2', 'QHXH26', 'CORR09', 'D3', 'D1', 'UMAHXH27', 'D2', 'QHXH27', 'CORR10', 'D3', 'D1', 'UMAHXH28', 'D2', 'QHXH28', 'CORR11', 'D3', 'D1', 'UMAHXH29', 'D2', 'QHXH29', 'CORR12', 'D3', 'D1', 'UMAHXH30', 'D2', 'QHXH30', 'CORR13', 'D3', 'D1', 'UMAHXH31', 'D2', 'QHXH31', 'CORR14', 'D3', 'D1', 'D4', 'D2', 'QHXH32', 'CORR15', 'D3', 'D1', 'UMAHXH33', 'D2', 'QHXH33', 'CORR16', 'D3', 'D1', 'UMAHXH34', 'D2', 'QHXH34', 'CORR17', 'D3', 'D1', 'UMAHXH35', 'D2', 'QHXH35', 'CORR18', 'D3', 'D1', 'UMAHXH36', 'D2', 'QHXH36', 'CORR19', 'D3', 'D1', 'UMAHXH37', 'D2', 'QHXH37', 'CORR20', 'D3', 'D1', 'UMAHXH38', 'D2', 'QHXH38', 'CORR21', 'D3', 'D1', 'UMAHXH39', 'D2', 'QHXH39', 'CORR22', 'D3', 'D1', 'UMAHXH40', 'D2', 'QHXH40', 'CORR23', 'D3', 'D1', 'UMAHXH41', 'D2', 'QHXH41', 'CORR24', 'D3', 'D1', 'UMAHXH42', 'D2', 'QHXH42', 'CORR25', 'D3', 'D1', 'UMAHXH43', 'D2', 'QHXH43', 'CORR26', 'D3', 'D1', 'UMAHXH44', 'D2', 'QHXH44', 'CORR27', 'D3', 'D1', 'UMAHXH45', 'D2', 'QHXH45', 'CORR28', 'D3', 'D1', 'UMAHXH46', 'D2', 'QHXH46', 'CORR29', 'D3', 'D1', 'UMAHXH47', 'D2', 'QHXH47', 'CORR30', 'D3', 'D1', 'UMAHXH48', 'D2', 'QHXH48', 'CORR31', 'D3', 'D1', 'UMAHXH49', 'D2', 'QHXH49', 'CORR32', 'D3', 'D1', 'UMAHXH50', 'D2', 'QHXH50', 'CORR33', 'D3']),
#  'LCLS2_HXR_U1': Line(label='', type='line', elements=['D1', 'UMAHXH17', 'D2', 'QHXH17', 'CORR00', 'D3', 'D1', 'UMAHXH18', 'D2', 'QHXH18', 'CORR01', 'D3', 'D1', 'UMAHXH19', 'D2', 'QHXH19', 'CORR02', 'D3', 'D1', 'UMAHXH20', 'D2', 'QHXH20', 'CORR03', 'D3', 'D1', 'UMAHXH21', 'D2', 'QHXH21', 'CORR04', 'D3', 'D1', 'UMAHXH22', 'D2', 'QHXH22', 'CORR05', 'D3', 'D1', 'UMAHXH23', 'D2', 'QHXH23', 'CORR06', 'D3']),
#  'LCLS2_HXR_U2': Line(label='', type='line', elements=['D1', 'UMAHXH25', 'D2', 'QHXH25', 'CORR08', 'D3', 'D1', 'UMAHXH26', 'D2', 'QHXH26', 'CORR09', 'D3', 'D1', 'UMAHXH27', 'D2', 'QHXH27', 'CORR10', 'D3', 'D1', 'UMAHXH28', 'D2', 'QHXH28', 'CORR11', 'D3', 'D1', 'UMAHXH29', 'D2', 'QHXH29', 'CORR12', 'D3', 'D1', 'UMAHXH30', 'D2', 'QHXH30', 'CORR13', 'D3', 'D1', 'UMAHXH31', 'D2', 'QHXH31', 'CORR14', 'D3', 'D1', 'D4', 'D2', 'QHXH32', 'CORR15', 'D3', 'D1', 'UMAHXH33', 'D2', 'QHXH33', 'CORR16', 'D3', 'D1', 'UMAHXH34', 'D2', 'QHXH34', 'CORR17', 'D3', 'D1', 'UMAHXH35', 'D2', 'QHXH35', 'CORR18', 'D3', 'D1', 'UMAHXH36', 'D2', 'QHXH36', 'CORR19', 'D3', 'D1', 'UMAHXH37', 'D2', 'QHXH37', 'CORR20', 'D3', 'D1', 'UMAHXH38', 'D2', 'QHXH38', 'CORR21', 'D3', 'D1', 'UMAHXH39', 'D2', 'QHXH39', 'CORR22', 'D3', 'D1', 'UMAHXH40', 'D2', 'QHXH40', 'CORR23', 'D3', 'D1', 'UMAHXH41', 'D2', 'QHXH41', 'CORR24', 'D3', 'D1', 'UMAHXH42', 'D2', 'QHXH42', 'CORR25', 'D3', 'D1', 'UMAHXH43', 'D2', 'QHXH43', 'CORR26', 'D3', 'D1', 'UMAHXH44', 'D2', 'QHXH44', 'CORR27', 'D3', 'D1', 'UMAHXH45', 'D2', 'QHXH45', 'CORR28', 'D3', 'D1', 'UMAHXH46', 'D2', 'QHXH46', 'CORR29', 'D3', 'D1', 'UMAHXH47', 'D2', 'QHXH47', 'CORR30', 'D3', 'D1', 'UMAHXH48', 'D2', 'QHXH48', 'CORR31', 'D3', 'D1', 'UMAHXH49', 'D2', 'QHXH49', 'CORR32', 'D3', 'D1', 'UMAHXH50', 'D2', 'QHXH50', 'CORR33', 'D3'])}

# %% [markdown]
# This `input` object is a convenient dataclass which contains all of the namelists and offers some convenience methods.

# %% [markdown]
# We can see the Genesis 4 representation by looking at `str(lat)` or `lat.to_genesis()`:

# %%
print(lat.to_genesis())
# Out:
# QHXH17: quadrupole = {l=0.101, k1=1.78};
# QHXH18: quadrupole = {l=0.101, k1=-1.78};
# QHXH19: quadrupole = {l=0.101, k1=1.78};
# QHXH20: quadrupole = {l=0.101, k1=-1.78};
# QHXH21: quadrupole = {l=0.101, k1=1.78};
# QHXH22: quadrupole = {l=0.101, k1=-1.78};
# QHXH23: quadrupole = {l=0.101, k1=1.78};
# QHXH24: quadrupole = {l=0.101, k1=-1.78};
# QHXH25: quadrupole = {l=0.101, k1=1.78};
# QHXH26: quadrupole = {l=0.101, k1=-1.78};
# QHXH27: quadrupole = {l=0.101, k1=1.78};
# QHXH28: quadrupole = {l=0.101, k1=-1.78};
# QHXH29: quadrupole = {l=0.101, k1=1.78};
# QHXH30: quadrupole = {l=0.101, k1=-1.78};
# QHXH31: quadrupole = {l=0.101, k1=1.78};
# QHXH32: quadrupole = {l=0.101, k1=-1.78};
# QHXH33: quadrupole = {l=0.101, k1=1.78};
# QHXH34: quadrupole = {l=0.101, k1=-1.78};
# QHXH35: quadrupole = {l=0.101, k1=1.78};
# QHXH36: quadrupole = {l=0.101, k1=-1.78};
# QHXH37: quadrupole = {l=0.101, k1=1.78};
# QHXH38: quadrupole = {l=0.101, k1=-1.78};
# QHXH39: quadrupole = {l=0.101, k1=1.78};
# QHXH40: quadrupole = {l=0.101, k1=-1.78};
# QHXH41: quadrupole = {l=0.101, k1=1.78};
# QHXH42: quadrupole = {l=0.101, k1=-1.78};
# QHXH43: quadrupole = {l=0.101, k1=1.78};
# QHXH44: quadrupole = {l=0.101, k1=-1.78};
# QHXH45: quadrupole = {l=0.101, k1=1.78};
# QHXH46: quadrupole = {l=0.101, k1=-1.78};
# QHXH47: quadrupole = {l=0.101, k1=1.78};
# QHXH48: quadrupole = {l=0.101, k1=-1.78};
# QHXH49: quadrupole = {l=0.101, k1=1.78};
# QHXH50: quadrupole = {l=0.101, k1=-1.78};
# UMAHXH17: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH18: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH19: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH20: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH21: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH22: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH23: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH25: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH26: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH27: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH28: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH29: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH30: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH31: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH33: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH34: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH35: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH36: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH37: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH38: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH39: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH40: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH41: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH42: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH43: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH44: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH45: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH46: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH47: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH48: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH49: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# UMAHXH50: undulator = {aw=1.7017, lambdau=0.026, nwig=130};
# CORR00: corrector = {l=0.001};
# CORR01: corrector = {l=0.001};
# CORR02: corrector = {l=0.001};
# CORR03: corrector = {l=0.001};
# CORR04: corrector = {l=0.001};
# CORR05: corrector = {l=0.001};
# CORR06: corrector = {l=0.001};
# CORR07: corrector = {l=0.001};
# CORR08: corrector = {l=0.001};
# CORR09: corrector = {l=0.001};
# CORR10: corrector = {l=0.001};
# CORR11: corrector = {l=0.001};
# CORR12: corrector = {l=0.001};
# CORR13: corrector = {l=0.001};
# CORR14: corrector = {l=0.001};
# CORR15: corrector = {l=0.001};
# CORR16: corrector = {l=0.001};
# CORR17: corrector = {l=0.001};
# CORR18: corrector = {l=0.001};
# CORR19: corrector = {l=0.001};
# CORR20: corrector = {l=0.001};
# CORR21: corrector = {l=0.001};
# CORR22: corrector = {l=0.001};
# CORR23: corrector = {l=0.001};
# CORR24: corrector = {l=0.001};
# CORR25: corrector = {l=0.001};
# CORR26: corrector = {l=0.001};
# CORR27: corrector = {l=0.001};
# CORR28: corrector = {l=0.001};
# CORR29: corrector = {l=0.001};
# CORR30: corrector = {l=0.001};
# CORR31: corrector = {l=0.001};
# CORR32: corrector = {l=0.001};
# CORR33: corrector = {l=0.001};
# D1: drift = {l=0.1335};
# D2: drift = {l=0.4615};
# D3: drift = {l=0.328};
# D4: drift = {l=3.4};
# HXRSS: chicane = {l=4.55, lb=0.1};
# HXR: LINE = {D1, UMAHXH17, D2, QHXH17, CORR00, D3, D1, UMAHXH18, D2, QHXH18, CORR01, D3, D1, UMAHXH19, D2, QHXH19, CORR02, D3, D1, UMAHXH20, D2, QHXH20, CORR03, D3, D1, UMAHXH21, D2, QHXH21, CORR04, D3, D1, UMAHXH22, D2, QHXH22, CORR05, D3, D1, UMAHXH23, D2, QHXH23, CORR06, D3, D1, HXRSS, D2, QHXH24, CORR07, D3, D1, UMAHXH25, D2, QHXH25, CORR08, D3, D1, UMAHXH26, D2, QHXH26, CORR09, D3, D1, UMAHXH27, D2, QHXH27, CORR10, D3, D1, UMAHXH28, D2, QHXH28, CORR11, D3, D1, UMAHXH29, D2, QHXH29, CORR12, D3, D1, UMAHXH30, D2, QHXH30, CORR13, D3, D1, UMAHXH31, D2, QHXH31, CORR14, D3, D1, D4, D2, QHXH32, CORR15, D3, D1, UMAHXH33, D2, QHXH33, CORR16, D3, D1, UMAHXH34, D2, QHXH34, CORR17, D3, D1, UMAHXH35, D2, QHXH35, CORR18, D3, D1, UMAHXH36, D2, QHXH36, CORR19, D3, D1, UMAHXH37, D2, QHXH37, CORR20, D3, D1, UMAHXH38, D2, QHXH38, CORR21, D3, D1, UMAHXH39, D2, QHXH39, CORR22, D3, D1, UMAHXH40, D2, QHXH40, CORR23, D3, D1, UMAHXH41, D2, QHXH41, CORR24, D3, D1, UMAHXH42, D2, QHXH42, CORR25, D3, D1, UMAHXH43, D2, QHXH43, CORR26, D3, D1, UMAHXH44, D2, QHXH44, CORR27, D3, D1, UMAHXH45, D2, QHXH45, CORR28, D3, D1, UMAHXH46, D2, QHXH46, CORR29, D3, D1, UMAHXH47, D2, QHXH47, CORR30, D3, D1, UMAHXH48, D2, QHXH48, CORR31, D3, D1, UMAHXH49, D2, QHXH49, CORR32, D3, D1, UMAHXH50, D2, QHXH50, CORR33, D3};
# LCLS2_HXR_U1: LINE = {D1, UMAHXH17, D2, QHXH17, CORR00, D3, D1, UMAHXH18, D2, QHXH18, CORR01, D3, D1, UMAHXH19, D2, QHXH19, CORR02, D3, D1, UMAHXH20, D2, QHXH20, CORR03, D3, D1, UMAHXH21, D2, QHXH21, CORR04, D3, D1, UMAHXH22, D2, QHXH22, CORR05, D3, D1, UMAHXH23, D2, QHXH23, CORR06, D3};
# LCLS2_HXR_U2: LINE = {D1, UMAHXH25, D2, QHXH25, CORR08, D3, D1, UMAHXH26, D2, QHXH26, CORR09, D3, D1, UMAHXH27, D2, QHXH27, CORR10, D3, D1, UMAHXH28, D2, QHXH28, CORR11, D3, D1, UMAHXH29, D2, QHXH29, CORR12, D3, D1, UMAHXH30, D2, QHXH30, CORR13, D3, D1, UMAHXH31, D2, QHXH31, CORR14, D3, D1, D4, D2, QHXH32, CORR15, D3, D1, UMAHXH33, D2, QHXH33, CORR16, D3, D1, UMAHXH34, D2, QHXH34, CORR17, D3, D1, UMAHXH35, D2, QHXH35, CORR18, D3, D1, UMAHXH36, D2, QHXH36, CORR19, D3, D1, UMAHXH37, D2, QHXH37, CORR20, D3, D1, UMAHXH38, D2, QHXH38, CORR21, D3, D1, UMAHXH39, D2, QHXH39, CORR22, D3, D1, UMAHXH40, D2, QHXH40, CORR23, D3, D1, UMAHXH41, D2, QHXH41, CORR24, D3, D1, UMAHXH42, D2, QHXH42, CORR25, D3, D1, UMAHXH43, D2, QHXH43, CORR26, D3, D1, UMAHXH44, D2, QHXH44, CORR27, D3, D1, UMAHXH45, D2, QHXH45, CORR28, D3, D1, UMAHXH46, D2, QHXH46, CORR29, D3, D1, UMAHXH47, D2, QHXH47, CORR30, D3, D1, UMAHXH48, D2, QHXH48, CORR31, D3, D1, UMAHXH49, D2, QHXH49, CORR32, D3, D1, UMAHXH50, D2, QHXH50, CORR33, D3};

# %% [markdown]
# The parser also works directly with strings if you prefer. Try the following:

# %%
lat = Lattice.from_contents(
    """
CORR32: corrector = {l=0.001};
CORR33: corrector = {l=0.002};
"""
)

# %%
lat
# Out:
# Lattice(elements={'CORR32': Corrector(label='', type='corrector', L=0.001, cx=0.0, cy=0.0), 'CORR33': Corrector(label='', type='corrector', L=0.002, cx=0.0, cy=0.0)}, filename=PosixPath('unknown'))
